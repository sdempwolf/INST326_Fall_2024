# %% [markdown]
# ## INST326 OOP Lab 00W00

# %% [markdown]
# Rename this notebook, replacing _Assignment with _YourName<br>
# Insert Signature Block Here

# %% [markdown]
# ### <font color=red>Instructions for TA</font>
# > <font color=red>Use this template for creating lab notebooks. Most of the formatting is intact. Look at the markdown HTML code for this cell for a few formatting tools. For example use the font color=green tag to change font colors to green when referencing python code or variables in the text. I have found that when you copy and paste from the google doc, there may be stray formatting characters, so it is best to retype the affected text inside the html tags. To indent text, start the line with a ">" followed by a space. To add a new line use "br tag" like this (look at the markdown code).<br>Delete this markdown cell when you are finished with it.</font>

# %% [markdown]
# ### Exercises
# Complete the following exercises in the code cells provided. Add your comments in the code cells as necessary. These exercises cover [add description here]

# %% [markdown]
# #### 1. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 2. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 3. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 4. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 5. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 6. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 7. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 8. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 9. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# #### 10. Title
# >  Description

# %%
# Solution - enter your code solution below

# %% [markdown]
# ### Notebook Instructions
# > Before turning in your notebook:
# > 1. Make sure you have renamed the notebook file as instructed
# > 2. Make sure you have included your signature block and that it is correct according to the instructions
# > 3. comment your code as necessary
# > 4. run all code cells and double check that they run correctly<br><br>
# Turn in your notebook by uploading it to ELMS<br>
# IF the exercises involve saved data files, put your notebook and the data file(s) in a zip folder and upload the zip folder to ELMS
