# %% [markdown]
# ### Prject 2 AI-Generated Examples
# The following examples are provided to illustrate *some* but not all of the requirements for the three project choices for project 2. They are intended to give you some ideas, not to provide copy and paste code. These examples work, but they are not complete in terms of the functional requirements described in project 2. They do not follow the requirements of project 2 in terms of the required "app class" template. Full requirements will be provided in the Project 2 Assignment. These programs are not particularly well-structure from an OOP perspective, nor are the especially readable. For these reasons, you may study them, but do not copy them.

# %% [markdown]
# #### FOR ILLUSTRATION PURPOSES ONLY. DO NOT COPY.

# %% [markdown]
# #### Option 1: A Calculator App.

# %%
import tkinter as tk

class Calculator:
    def __init__(self):
        self.current = ""
        self.total = 0
        self.operator = ""
    
    def add_digit(self, digit):
        self.current += str(digit)
        self.update_display()
    
    def set_operator(self, operator):
        if self.current:
            self.total = int(self.current)
            self.current = ""
            self.operator = operator
    
    def calculate(self):
        if self.current and self.operator:
            if self.operator == "+":
                self.total += int(self.current)
            elif self.operator == "-":
                self.total -= int(self.current)
            elif self.operator == "*":
                self.total *= int(self.current)
            elif self.operator == "/":
                self.total /= int(self.current)
            self.current = str(self.total)
            self.update_display()
            self.current = ""
    
    def update_display(self):
        display_var.set(self.current or self.total)
    
    def clear(self):
        self.current = ""
        self.total = 0
        self.operator = ""
        self.update_display()

app = tk.Tk()
app.title("Simple Calculator")

calc = Calculator()
display_var = tk.StringVar()

display = tk.Entry(app, textvariable=display_var, font=("Arial", 20), bd=10, insertwidth=4, borderwidth=4)
display.grid(row=0, column=0, columnspan=4)

buttons = [
    ('7', 1, 0), ('8', 1, 1), ('9', 1, 2), ('/', 1, 3),
    ('4', 2, 0), ('5', 2, 1), ('6', 2, 2), ('*', 2, 3),
    ('1', 3, 0), ('2', 3, 1), ('3', 3, 2), ('-', 3, 3),
    ('0', 4, 0), ('C', 4, 1), ('=', 4, 2), ('+', 4, 3),
]

for (text, row, col) in buttons:
    action = lambda x=text: calc.add_digit(x) if x.isdigit() else \
             (calc.set_operator(x) if x in "+-*/" else calc.calculate() if x == "=" else calc.clear())
    tk.Button(app, text=text, padx=20, pady=20, font=("Arial", 18), command=action).grid(row=row, column=col)

app.mainloop()

# %% [markdown]
# #### Option 2: A To-Do List App

# %%
import tkinter as tk
from tkinter import messagebox

class Task:
    def __init__(self, description):
        self.description = description
        self.completed = False

    def __str__(self):
        return f"{'[x]' if self.completed else '[ ]'} {self.description}"

class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append(task)
        self.update_display()

    def delete_task(self, index):
        if 0 <= index < len(self.tasks):
            del self.tasks[index]
            self.update_display()

    def toggle_task(self, index):
        if 0 <= index < len(self.tasks):
            self.tasks[index].completed = not self.tasks[index].completed
            self.update_display()

    def update_display(self):
        listbox.delete(0, tk.END)
        for task in self.tasks:
            listbox.insert(tk.END, str(task))

def add_task():
    description = entry.get()
    if description:
        todo_list.add_task(Task(description))
        entry.delete(0, tk.END)
    else:
        messagebox.showwarning("Input Error", "Please enter a task description.")

def delete_task():
    selected_index = listbox.curselection()
    if selected_index:
        todo_list.delete_task(selected_index[0])
    else:
        messagebox.showwarning("Selection Error", "Please select a task to delete.")

def toggle_task():
    selected_index = listbox.curselection()
    if selected_index:
        todo_list.toggle_task(selected_index[0])
    else:
        messagebox.showwarning("Selection Error", "Please select a task to toggle.")

app = tk.Tk()
app.title("To-Do List")

todo_list = ToDoList()

entry = tk.Entry(app, width=50)
entry.pack(pady=10)

button_frame = tk.Frame(app)
button_frame.pack(pady=10)

add_button = tk.Button(button_frame, text="Add Task", command=add_task)
add_button.pack(side=tk.LEFT, padx=5)

delete_button = tk.Button(button_frame, text="Delete Task", command=delete_task)
delete_button.pack(side=tk.LEFT, padx=5)

toggle_button = tk.Button(button_frame, text="Toggle Task", command=toggle_task)
toggle_button.pack(side=tk.LEFT, padx=5)

listbox = tk.Listbox(app, width=50, height=10)
listbox.pack(pady=10)

app.mainloop()

# %% [markdown]
# #### Option 3: A Contact List App

# %%
import tkinter as tk
from tkinter import messagebox

class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def __str__(self):
        return f"{self.name}: {self.phone}"

class ContactBook:
    def __init__(self):
        self.contacts = []
        self.load_contacts()

    def add_contact(self, contact):
        self.contacts.append(contact)
        self.save_contacts()
        self.update_display()

    def delete_contact(self, index):
        if 0 <= index < len(self.contacts):
            del self.contacts[index]
            self.save_contacts()
            self.update_display()

    def search_contact(self, name):
        for contact in self.contacts:
            if contact.name.lower() == name.lower():
                return contact
        return None

    def update_display(self):
        listbox.delete(0, tk.END)
        for contact in self.contacts:
            listbox.insert(tk.END, str(contact))

    def save_contacts(self):
        with open("contacts.txt", "w") as file:
            for contact in self.contacts:
                file.write(f"{contact.name},{contact.phone}\n")

    def load_contacts(self):
        try:
            with open("contacts.txt", "r") as file:
                for line in file:
                    name, phone = line.strip().split(",")
                    self.contacts.append(Contact(name, phone))
        except FileNotFoundError:
            pass

def add_contact():
    name = name_entry.get()
    phone = phone_entry.get()
    if name and phone:
        contact_book.add_contact(Contact(name, phone))
        name_entry.delete(0, tk.END)
        phone_entry.delete(0, tk.END)
    else:
        messagebox.showwarning("Input Error", "Please enter both name and phone number.")

def delete_contact():
    selected_index = listbox.curselection()
    if selected_index:
        contact_book.delete_contact(selected_index[0])
    else:
        messagebox.showwarning("Selection Error", "Please select a contact to delete.")

def search_contact():
    name = name_entry.get()
    contact = contact_book.search_contact(name)
    if contact:
        messagebox.showinfo("Search Result", str(contact))
    else:
        messagebox.showinfo("Search Result", "Contact not found.")

app = tk.Tk()
app.title("Contact Book")

contact_book = ContactBook()

name_entry = tk.Entry(app, width=30)
name_entry.pack(pady=10)
name_entry.insert(0, "Name")

phone_entry = tk.Entry(app, width=30)
phone_entry.pack(pady=10)
phone_entry.insert(0, "Phone")

button_frame = tk.Frame(app)
button_frame.pack(pady=10)

add_button = tk.Button(button_frame, text="Add Contact", command=add_contact)
add_button.pack(side=tk.LEFT, padx=5)

delete_button = tk.Button(button_frame, text="Delete Contact", command=delete_contact)
delete_button.pack(side=tk.LEFT, padx=5)

search_button = tk.Button(button_frame, text="Search Contact", command=search_contact)
search_button.pack(side=tk.LEFT, padx=5)

listbox = tk.Listbox(app, width=50, height=10)
listbox.pack(pady=10)

app.mainloop()

# %% [markdown]
# All three examples were generated by OpenAI Chat GPT, August 2024.
